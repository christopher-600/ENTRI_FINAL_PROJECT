# %%
# ## Data Analytics Final Project
# ## Topic: "BMW Sales Analytics and Market Trends (2010–2024): A Data-Driven Study of Models, Pricing, and Consumer Preferences"
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\PROJECT CHRIS\BMW sales data (2010-2024).csv")

# %%
print(df.head())
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0    151748.0    98740.0          8300                 High
# 1    121671.0    79219.0          3428                  Low
# 2     10991.0   113265.0          6994                  Low
# 3     27255.0    60971.0          4047                  Low
# 4    122131.0    49898.0          3080                  Low

# %%
rows, cols = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")
# Out:
# Number of rows: 50000
# Number of columns: 11

# %%
print("Dataset shape (rows, columns):", df.shape)
# Out:
# Dataset shape (rows, columns): (50000, 11)

# %%
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['Model', 'Year', 'Region', 'Color', 'Fuel_Type', 'Transmission', 'Engine_Size_L', 'Mileage_KM', 'Price_USD', 'Sales_Volume', 'Sales_Classification']

# %%
print("\nInfo about dataset:")
print(df.info())
# Out:
# Info about dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 50000 non-null  object
#  1   Year                  50000 non-null  int64
#  2   Region                50000 non-null  object
#  3   Color                 50000 non-null  object
#  4   Fuel_Type             50000 non-null  object
#  5   Transmission          50000 non-null  object
#  6   Engine_Size_L         50000 non-null  float64
#  7   Mileage_KM            50000 non-null  int64
#  8   Price_USD             50000 non-null  int64
#  9   Sales_Volume          50000 non-null  int64
#  10  Sales_Classification  50000 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 4.2+ MB
# None

# %%
print("\nFirst 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
print("\nSummary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#                Year  Engine_Size_L     Mileage_KM      Price_USD  Sales_Volume
# count  50000.000000   50000.000000   50000.000000   50000.000000  50000.000000
# mean    2017.015700       3.247180  100307.203140   75034.600900   5067.514680
# std        4.324459       1.009078   57941.509344   25998.248882   2856.767125
# min     2010.000000       1.500000       3.000000   30000.000000    100.000000
# 25%     2013.000000       2.400000   50178.000000   52434.750000   2588.000000
# 50%     2017.000000       3.200000  100388.500000   75011.500000   5087.000000
# 75%     2021.000000       4.100000  150630.250000   97628.250000   7537.250000
# max     2024.000000       5.000000  199996.000000  119998.000000   9999.000000

# %%
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Model                   0
# Year                    0
# Region                  0
# Color                   0
# Fuel_Type               0
# Transmission            0
# Engine_Size_L           0
# Mileage_KM              0
# Price_USD               0
# Sales_Volume            0
# Sales_Classification    0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Model                   0
# Year                    0
# Region                  0
# Color                   0
# Fuel_Type               0
# Transmission            0
# Engine_Size_L           0
# Mileage_KM              0
# Price_USD               0
# Sales_Volume            0
# Sales_Classification    0
# dtype: int64

# %%
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Model                   0.0
# Year                    0.0
# Region                  0.0
# Color                   0.0
# Fuel_Type               0.0
# Transmission            0.0
# Engine_Size_L           0.0
# Mileage_KM              0.0
# Price_USD               0.0
# Sales_Volume            0.0
# Sales_Classification    0.0
# dtype: float64

# %%
df_clean = df.dropna()

# %%
df_clean = df.dropna(axis=1)

# %%
print("Total duplicates:", df.duplicated().sum())
# Out:
# Total duplicates: 0

# %%
df['Model'] = df['Model'].astype('category')

# %%
print(df.dtypes)
# Out:
# Model                   category
# Year                       int64
# Region                  category
# Color                     object
# Fuel_Type                 object
# Transmission              object
# Engine_Size_L            float64
# Mileage_KM                 int64
# Price_USD                  int64
# Sales_Volume               int64
# Sales_Classification      object
# dtype: object

# %%
print(df.head())
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
df = df.astype({
    "Model": "category",
    "Year": "int64",
    "Region": "category",
    "Color": "category",
    "Fuel_Type": "category",
    "Transmission": "category",
    "Engine_Size_L": "float64",
    "Mileage_KM": "float64",
    "Price_USD": "float64",
    "Sales_Volume": "int64",
    "Sales_Classification": "category"
})

# %%
print(df.dtypes)
# Out:
# Model                   category
# Year                       int64
# Region                  category
# Color                   category
# Fuel_Type               category
# Transmission            category
# Engine_Size_L            float64
# Mileage_KM               float64
# Price_USD                float64
# Sales_Volume               int64
# Sales_Classification    category
# dtype: object

# %%
df['Mileage_KM'] = df['Mileage_KM'].astype(str)

# %%
df['Mileage_KM'] = df['Mileage_KM'].str.replace(" km","", regex=False)
df['Mileage_KM'] = df['Mileage_KM'].str.replace(",","", regex=False)
df['Mileage_KM'] = pd.to_numeric(df['Mileage_KM'], errors='coerce')

# %%
df['Price_USD'] = df['Price_USD'].astype(str)
df['Price_USD'] = df['Price_USD'].str.replace("[$,]","", regex=True)
df['Price_USD'] = pd.to_numeric(df['Price_USD'], errors='coerce')

# %%
categorical_cols = ['Model','Region','Color','Fuel_Type','Transmission','Sales_Classification']
for col in categorical_cols:
    df[col] = df[col].astype('category')

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce').astype('Int64')
df['Sales_Volume'] = pd.to_numeric(df['Sales_Volume'], errors='coerce').astype('Int64')

# %%
print(df.dtypes)
print(df.head())
# Out:
# Model                   category
# Year                       Int64
# Region                  category
# Color                   category
# Fuel_Type               category
# Transmission            category
# Engine_Size_L            float64
# Mileage_KM               float64
# Price_USD                float64
# Sales_Volume               Int64
# Sales_Classification    category
# dtype: object
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# ...

# %%
df_2020 = df[df['Year'] == 2020]

# %%
df_europe_diesel = df[(df['Region'] == 'Europe') & (df['Fuel_Type'] == 'Diesel')]

# %%
df_price_range = df[(df['Price_USD'] >= 30000) & (df['Price_USD'] <= 50000)]

# %%
expensive_models = avg_price_model[avg_price_model['Price_USD'] > 60000]

# %%
high_sales_regions = total_sales_region[total_sales_region['Sales_Volume'] > 5000]

# %%
print("\nHigh Price Models:\n", expensive_models)
# Out:
# High Price Models:
#         Model     Price_USD
# 0   3 Series  75566.233950
# 1   5 Series  75287.844077
# 2   7 Series  75570.196742
# 3         M3  74841.588715
# 4         M5  74474.930996
# 5         X1  75262.219037
# 6         X3  75016.616856
# 7         X5  74708.116782
# 8         X6  74434.600491
# 9         i3  74800.268081
# 10        i8  75366.270951

# %%
df_2020 = df[df['Year'] == 2020]

# %%
df_europe_diesel = df[(df['Region']=='Europe') & (df['Fuel_Type']=='Diesel')]

# %%
df_price_range = df[(df['Price_USD'] >= 30000) & (df['Price_USD'] <= 50000)]

# %%
print("Average Price by Model:\n", avg_price_model.head())
# Out:
# Average Price by Model:
#        Model     Price_USD
# 0  3 Series  75566.233950
# 1  5 Series  75287.844077
# 2  7 Series  75570.196742
# 3        M3  74841.588715
# 4        M5  74474.930996

# %%
#VISUALIZATION

# %%
#Trend Analysis Over Time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\Admin\Desktop\PROJECT CHRIS\BMW sales data (2010-2024).csv"
bmw_data = pd.read_csv(file_path)

# %%
print("Data Loaded Successfully!")
print(bmw_data.head())
print(bmw_data.info())
# Out:
# Data Loaded Successfully!
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
# ...

# %%
sales_by_year = bmw_data.groupby('Year')['Sales_Volume'].sum().reset_index()

plt.figure(figsize=(12,6))
sns.lineplot(data=sales_by_year, x='Year', y='Sales_Volume', marker='o')
plt.title('Total BMW Sales Volume Over the Years')
plt.xlabel('Year')
plt.ylabel('Sales Volume')
plt.grid(True)
plt.show()

# %%
#Top 10 BMW Models by Sales Volume

# %%
sales_by_model = bmw_data.groupby('Model')['Sales_Volume'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))
sales_by_model.plot(kind='bar')
plt.title('Top 10 BMW Models by Sales Volume')
plt.xlabel('Model')
plt.ylabel('Sales Volume')
plt.xticks(rotation=45)
plt.show()

# %%
#Market Share by Region

# %%
sales_by_region = bmw_data.groupby('Region')['Sales_Volume'].sum()

plt.figure(figsize=(8,8))
sales_by_region.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Market Share by Region')
plt.ylabel('')
plt.show()

# %%
#Yearly Sales Trend with Moving Average

# %%
sales_by_year = bmw_data.groupby('Year')['Sales_Volume'].sum().reset_index()
sales_by_year['Moving_Avg'] = sales_by_year['Sales_Volume'].rolling(window=3).mean()

plt.figure(figsize=(12,6))
sns.lineplot(data=sales_by_year, x='Year', y='Sales_Volume', label='Annual Sales')
sns.lineplot(data=sales_by_year, x='Year', y='Moving_Avg', label='3-Year Moving Avg', linestyle='--')
plt.title('BMW Sales Trend with Moving Average')
plt.xlabel('Year')
plt.ylabel('Sales Volume')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Regional Performance Over Time

# %%
sales_region_year = bmw_data.groupby(['Year', 'Region'])['Sales_Volume'].sum().reset_index()

plt.figure(figsize=(12,8))
sns.lineplot(data=sales_region_year, x='Year', y='Sales_Volume', hue='Region')
plt.title('Regional Sales Trends Over the Years')
plt.xlabel('Year')
plt.ylabel('Sales Volume')
plt.legend(title='Region')
plt.grid(True)
plt.show()

# %%
#Sales Classification vs Price and Mileage

# %%
plt.figure(figsize=(14,6))

plt.subplot(1, 2, 1)
sns.boxplot(data=bmw_data, x='Sales_Classification', y='Price_USD')
plt.title('Price Distribution by Sales Classification')
plt.xlabel('Sales Classification')
plt.ylabel('Price (USD)')

plt.subplot(1, 2, 2)
sns.boxplot(data=bmw_data, x='Sales_Classification', y='Mileage_KM')
plt.title('Mileage Distribution by Sales Classification')
plt.xlabel('Sales Classification')
plt.ylabel('Mileage (KM)')

plt.tight_layout()
plt.show()
